# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merged_df=pd.merge(mouse_metadata, study_results, on="Mouse ID", how='outer')

# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
merged_df['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

#
#Desired output: array(['g989'], dtype=object)
#

#duplicate_rows = df.duplicated(subset=['Mouse ID', 'Timepoint'])
duplicate_rows = merged_df.duplicated(subset=['Mouse ID', 'Timepoint'])

df2=merged_df[duplicate_rows] 
df2.head(10)

#drop_duplicates(subset=None, *, keep='first', inplace=False, ignore_index=False)[source]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates=merged_df[merged_df['Mouse ID']=='g989']
duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df=merged_df[merged_df['Mouse ID']!='g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

means=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].mean()
means

medians=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].median()
medians

var=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].var()
var

sd=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].std()
sd

sem=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].sem()
sem

d={}
d['mean']=means
d['median']=medians
d['var']=var
d['sd']=sd
d['sem']=sem

df=pd.DataFrame(d)
df
# Out:
#                    mean     median        var        sd       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
df2=clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].agg(['mean','median', 'var', 'std', 'sem'])
df2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
df3=clean_df.groupby("Drug Regimen")['Timepoint'].count()
df3.plot(x="Drug Regimen", y='Timepoint', kind='bar', xlabel="Drug Regimen", ylabel='Timepoint', title='Drug Regimen vs Timepoint')
# Out:
# <Axes: title={'center': 'Drug Regimen vs Timepoint'}, xlabel='Drug Regimen', ylabel='Timepoint'>

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(df3.index, height=df3)
plt.xticks(rotation='vertical')
plt.title("Drug Regimen vs Timepoint")
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoint")
plt.show()
#df3.index

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
df4=clean_df['Sex'].value_counts()
df4
df4.plot.pie(y="Sex",ylabel="Sex", autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(df4,autopct='%1.1f%%')
plt.title("Male")
plt.xlabel("Female")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

#time_df=clean_df.groupby('Mouse ID').max('Timepoint')
#print(time_df.head(300))

#Got this from classmate Christine Jauregui
#final_tumor_volume = deduped_merged_df.loc[deduped_merged_df.groupby(['Mouse ID', 'Drug Regimen']\)['Timepoint'].idxmax(), ['Mouse ID', 'Timepoint','Drug Regimen', 'Tumor Volume (mm3)']]
final_tumor_volume = clean_df.loc[clean_df.groupby(['Mouse ID', 'Drug Regimen'])['Timepoint'].idxmax(), ['Mouse ID', 'Timepoint','Drug Regimen', 'Tumor Volume (mm3)']]
#print('final_tumor_volume: ', final_tumor_volume)


#Subset based on treatment regimen being Capomulin, Ramicane, Infubinol, and Ceftamin

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint for each mouse

#merged_df=pd.merge(time_df, treatment_df, on="Mouse ID", how="left")
#merged_df

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments=['Capomulin','Ramicane','Infubinol','Ceftamin']
#treatments=['Capomulin']
#treatments=['Infubinol']
# Create empty list to fill with tumor vol data (for plotting)
vol=[]



# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:
    print("Treatment: ", treatment)

    #Subset of data

    #All timepoints
    #subset=clean_df[clean_df['Drug Regimen']==treatment]
    #data=subset['Tumor Volume (mm3)']
    
    #Only timepoint 45
    subset=final_tumor_volume[final_tumor_volume['Drug Regimen']==treatment]
    data=subset['Tumor Volume (mm3)']

    quartiles = data.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f"The lower quartile of tumor volume is: {lowerq}")
    print(f"The upper quartile of tumor volume is: {upperq}")
    print(f"The interquartile range of tumor volume is: {iqr}")
    print(f"The the median of tumor volume is: {quartiles[0.5]} ")
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")

    outliers=[]
    for x in data:
        #print("Hi! The x value is ", x )
        if x<lower_bound or x>upper_bound:
            outliers.append(x)
    print('\n')
    print(treatment, '\'s potential outliers: ', pd.Series(outliers))
    print('\n')
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds



#Desired output

#Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
#Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
#Infubinol's potential outliers: 31    36.321346
#Name: Tumor Volume (mm3), dtype: float64
#Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Out:
# Treatment:  Capomulin
# The lower quartile of tumor volume is: 32.37735684
# The upper quartile of tumor volume is: 40.1592203
# The interquartile range of tumor volume is: 7.781863460000004
# The the median of tumor volume is: 38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
#
#
# Capomulin 's potential outliers:  Series([], dtype: object)
#
#
# Treatment:  Ramicane
# The lower quartile of tumor volume is: 31.56046955
# The upper quartile of tumor volume is: 40.65900627
# The interquartile range of tumor volume is: 9.098536719999998
# The the median of tumor volume is: 36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.
#
#
# Ramicane 's potential outliers:  Series([], dtype: object)
#
#
# Treatment:  Infubinol
# The lower quartile of tumor volume is: 54.04860769
# The upper quartile of tumor volume is: 65.52574285
# ...

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
treatments=['Capomulin','Ramicane','Infubinol','Ceftamin']
final={}
for treatment in treatments:
    subset=final_tumor_volume[final_tumor_volume['Drug Regimen']==treatment]
    data=subset['Tumor Volume (mm3)']
    data=data.reset_index(drop=True)
    final[treatment]=data
    #print(data)

final_df=pd.DataFrame(final)
final_df.plot(kind='box', sym='ro')
# Out:
# <Axes: >

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
cap=clean_df[clean_df['Drug Regimen']=='Capomulin']
mouse_df=cap[cap['Mouse ID']=='l509']
mouse_df.index=[0,5,10,15,20,25,30,35,40,45]
#print(mouse_df['Tumor Volume (mm3)'])
plt.plot( mouse_df['Tumor Volume (mm3)'])
plt.title("Tumor Volume (mm3) vs Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Timepoint")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
cap_df=clean_df[clean_df['Drug Regimen']=='Capomulin']
group_df=cap_df.groupby(['Mouse ID'])[['Tumor Volume (mm3)', 'Weight (g)']].mean()
group_df


plt.scatter(group_df['Weight (g)'], group_df['Tumor Volume (mm3)'])
plt.title("mouse weight vs. the average observed tumor volume")
plt.xlabel("mouse weight")
plt.ylabel("average observed tumor volume")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Plot the different factors in a scatter plot
x_values = group_df['Weight (g)']
y_values = group_df['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
print(f"The r-squared is: {rvalue**2}")


#Correlation
corr=st.pearsonr(x_values, y_values)
print(f'The correlation is : {corr[0]}')


plt.show()
# Out:
# The r-squared is: 0.7088568047708723
# The correlation is : 0.8419363424694719
